# %% [markdown]
# <a href="https://colab.research.google.com/github/oferbaharav/DS-Unit-1-Sprint-4-Linear-Algebra/blob/master/module4-logistic-regression/Ofer_Baharav_Copy_of_assignment_regression_classification_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 1, Module 4*
#
# ---

# %% [markdown]
# # Logistic Regression
#
#
# ## Assignment 🌯
#
# You'll use a [**dataset of 400+ burrito reviews**](https://srcole.github.io/100burritos/). How accurately can you predict whether a burrito is rated 'Great'?
#
# > We have developed a 10-dimensional system for rating the burritos in San Diego. ... Generate models for what makes a burrito great and investigate correlations in its dimensions.
#
# - [ ] Do train/validate/test split. Train on reviews from 2016 & earlier. Validate on 2017. Test on 2018 & later.
# - [ ] Begin with baselines for classification.
# - [ ] Use scikit-learn for logistic regression.
# - [ ] Get your model's validation accuracy. (Multiple times if you try multiple iterations.)
# - [ ] Get your model's test accuracy. (One time, at the end.)
# - [ ] Commit your notebook to your fork of the GitHub repo.
# - [ ] Watch Aaron's [video #1](https://www.youtube.com/watch?v=pREaWFli-5I) (12 minutes) & [video #2](https://www.youtube.com/watch?v=bDQgVt4hFgY) (9 minutes) to learn about the mathematics of Logistic Regression.
#
#
# ## Stretch Goals
#
# - [ ] Add your own stretch goal(s) !
# - [ ] Make exploratory visualizations.
# - [ ] Do one-hot encoding.
# - [ ] Do [feature scaling](https://scikit-learn.org/stable/modules/preprocessing.html).
# - [ ] Get and plot your coefficients.
# - [ ] Try [scikit-learn pipelines](https://scikit-learn.org/stable/modules/compose.html).

# %%
# %%capture
import sys

# If you're on Colab:
if 'google.colab' in sys.modules:
    DATA_PATH = 'https://raw.githubusercontent.com/LambdaSchool/DS-Unit-2-Linear-Models/master/data/'
    # !pip install category_encoders==2.*

# If you're working locally:
else:
    DATA_PATH = '../data/'

# %%
# Load data downloaded from https://srcole.github.io/100burritos/
import pandas as pd
df = pd.read_csv(DATA_PATH+'burritos/burritos.csv')

# %%
df.head(2)
# Out:
#                Location      Burrito       Date  ... Avocado Corn Zucchini
# 0    Donato's taco shop  California   1/18/2016  ...     NaN  NaN      NaN
# 1  Oscar's Mexican food  California   1/24/2016  ...     NaN  NaN      NaN
#
# [2 rows x 66 columns]

# %%
# Derive binary classification target:
# We define a 'Great' burrito as having an
# overall rating of 4 or higher, on a 5 point scale.
# Drop unrated burritos.
df = df.dropna(subset=['overall'])
df['Great'] = df['overall'] >= 4

# %%
df.head(20)
# Out:
#                           Location             Burrito  ... Zucchini  Great
# 0               Donato's taco shop         California   ...      NaN  False
# 1             Oscar's Mexican food         California   ...      NaN  False
# 2             Oscar's Mexican food            Carnitas  ...      NaN  False
# 3             Oscar's Mexican food         Carne asada  ...      NaN  False
# 4                     Pollos Maria          California  ...      NaN   True
# 5                     Pollos Maria       combo chicken  ...      NaN  False
# 6                 Nico's Taco Shop          California  ...      NaN  False
# 7                 Nico's Taco Shop            Carnitas  ...      NaN  False
# 8          Los Primos Mexican Food  Monster California  ...      NaN  False
# 9                JV's Mexican Food         Carne Asada  ...      NaN  False
# 10               JV's Mexican Food         Surf & Turf  ...      NaN  False
# ...

# %%
# Clean/combine the Burrito categories
df['Burrito'] = df['Burrito'].str.lower()

california = df['Burrito'].str.contains('california')
asada = df['Burrito'].str.contains('asada')
surf = df['Burrito'].str.contains('surf')
carnitas = df['Burrito'].str.contains('carnitas')

df.loc[california, 'Burrito'] = 'California'
df.loc[asada, 'Burrito'] = 'Asada'
df.loc[surf, 'Burrito'] = 'Surf & Turf'
df.loc[carnitas, 'Burrito'] = 'Carnitas'
df.loc[~california & ~asada & ~surf & ~carnitas, 'Burrito'] = 'Other'

# %%
df.head(20)
# Out:
#                           Location      Burrito       Date  ... Corn Zucchini  Great
# 0               Donato's taco shop   California  1/18/2016  ...  NaN      NaN  False
# 1             Oscar's Mexican food   California  1/24/2016  ...  NaN      NaN  False
# 2             Oscar's Mexican food     Carnitas  1/24/2016  ...  NaN      NaN  False
# 3             Oscar's Mexican food        Asada  1/24/2016  ...  NaN      NaN  False
# 4                     Pollos Maria   California  1/27/2016  ...  NaN      NaN   True
# 5                     Pollos Maria        Other  1/28/2016  ...  NaN      NaN  False
# 6                 Nico's Taco Shop   California  1/30/2016  ...  NaN      NaN  False
# 7                 Nico's Taco Shop     Carnitas  1/30/2016  ...  NaN      NaN  False
# 8          Los Primos Mexican Food   California   2/1/2016  ...  NaN      NaN  False
# 9                JV's Mexican Food        Asada   2/6/2016  ...  NaN      NaN  False
# ...

# %%
df.select_dtypes(exclude='number').describe().T
# Out:
#               count  ... freq
# Location        421  ...   28
# Burrito         421  ...  169
# Date            421  ...   29
# Neighborhood     92  ...    9
# Address          88  ...    2
# URL              87  ...    2
# Chips            26  ...   21
# Rec             231  ...  155
# Reviewer        420  ...  147
# Notes           146  ...    2
# Unreliable       33  ...   33
# NonSD             7  ...    5
# Beef            179  ...  137
# Pico            158  ...  127
# Guac            154  ...  114
# Cheese          159  ...  128
# Fries           127  ...  102
# Sour cream       92  ...   67
# Pork             51  ...   36
# Chicken          21  ...   20
# Shrimp           21  ...   17
# Fish              6  ...    4
# Rice             36  ...   26
# Beans            35  ...   27
# Lettuce          11  ...    9
# Tomato            7  ...    5
# Bell peper        7  ...    4
# Carrots           1  ...    1
# Cabbage           8  ...    6
# Sauce            38  ...   33
# ...

# %%
# Drop some high cardinality categoricals
df = df.drop(columns=['Notes', 'Location', 'Reviewer', 'Address', 'URL', 'Neighborhood'])

# %%
# Drop some columns to prevent "leakage"
df = df.drop(columns=['Rec', 'overall'])

# %%
#Do train/validate/test split. 
#Train on reviews from 2016 & earlier. 
#Validate on 2017. 
#Test on 2018 & later.

#tried to do this with the automatic formula, threw an error name 'train not defined.
# I thought that's where we defined it as train, test = ?? but I guess I got it
#all wrong. Now going to split the sets per date as requested
# from sklearn.model_selection import train_test_split

# train, test = train_test_split(train, random_state=42)

# train.shape, test.shape

# %%
df.head(2)
# Out:
#       Burrito       Date  Yelp  Google Chips  ...  Sushi  Avocado  Corn  Zucchini  Great
# 0  California  1/18/2016   3.5     4.2   NaN  ...    NaN      NaN   NaN       NaN  False
# 1  California  1/24/2016   3.5     3.3   NaN  ...    NaN      NaN   NaN       NaN  False
#
# [2 rows x 59 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format=True)

# %%
#Train on reviews from 2016 & earlier. 
train = df[df['Date'].dt.year <= 2016]
train.shape
# Out:
# (298, 59)

# %%
#Validate on 2017.
val = df[df['Date'].dt.year == 2017]
val.shape
# Out:
# (85, 59)

# %%
#Test on 2018 & later.
test = df[df['Date'].dt.year >=2018]
test.shape
# Out:
# (38, 59)

# %%
target = 'Cost'

y_train = train[target]
y_train.value_counts(normalize=True)
# Out:
# 6.25    0.136364
# 7.50    0.054545
# 8.25    0.045455
# 6.99    0.045455
# 7.00    0.040909
#           ...
# 2.99    0.004545
# 4.95    0.004545
# 6.30    0.004545
# 7.14    0.004545
# 6.02    0.004545
# Name: Cost, Length: 73, dtype: float64

# %%
majority_class = y_train.mode()[0]
y_pred = [majority_class] * len(y_train)
y_pred
# Out:
# [6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
#  6.25,
# ...

# %%
from sklearn.metrics import accuracy_score
import numpy as np
from sklearn.impute import SimpleImputer
features = df.dropna(df[['Google', 'Yelp', 'Great']])
features = SimpleImputer(missing_values=np.nan, strategy='mean')
target = features = SimpleImputer(missing_values=np.nan, strategy='mean')
accuracy_score(y_train, y_pred)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-9e529aaac832> in <module>()
#       2 import numpy as np
#       3 from sklearn.impute import SimpleImputer
# ----> 4 features = df.dropna(df[['Google', 'Yelp', 'Great']])
#       5 features = SimpleImputer(missing_values=np.nan, strategy='mean')
#       6 target = features = SimpleImputer(missing_values=np.nan, strategy='mean')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4848                 result = result.dropna(how=how, thresh=thresh, subset=subset, axis=ax)
#    4849         else:
# -> 4850             axis = self._get_axis_number(axis)
#    4851             agg_axis = 1 - axis
#    4852
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     400     @classmethod
# ...

# %%
y_val = val[target]
y_pred = [majority_class] * len(y_val)
accuracy_score(y_val, y_pred)
# Out:
# 0.5529411764705883

# %%
# 1. Import estimator class
from sklearn.linear_model import LinearRegression

# 2. Instantiate this class
linear_reg = LinearRegression()

# 3. Arrange X feature matrices (already did y target vectors)

features = dropna(['Google', 'Yelp', 'Great'])
X_train = train[features]
y_train = train[target]
X_val = val[features]
# X_val = train[features]
# y_val = 
# X_test
# y_test 

# Impute missing values
from sklearn.impute import SimpleImputer
imputer = SimpleImputer()
X_train_imputed = imputer.fit_transform(X_train)
X_val_imputed = imputer.transform(X_val)

# 4. Fit the model
linear_reg.fit(X_train_imputed, y_train)

# 5. Apply the model to new data.
# The predictions look like this ...
linear_reg.predict(X_val_imputed)

## What do these numbers mean?
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-49ce7dd63f07> in <module>()
#       6 # 3. Arrange X feature matrices (already did y target vectors)
#       7
# ----> 8 features = dropna(['Google', 'Yelp', 'Great'])
#       9 X_train = train[features]
#      10 y_train = train[target]
#
# NameError: name 'dropna' is not defined

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(solver='lbfgs')
log_reg.fit(X_train_imputed, y_train)
print('Validation Accuracy 1', log_reg.score(X_val_imputed, y_val))
# Out:
# Validation Accuracy 1 1.0

# %%
pd.Series(linear_reg.coef_, features)
# Out:
# Google    5.144943e-16
# Yelp     -1.110223e-16
# Great     1.000000e+00
# dtype: float64

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(solver='lbfgs')
log_reg.fit(X_train_imputed, y_train)
print('Validation Accuracy', log_reg.score(X_val_imputed, y_val))
# Out:
# Validation Accuracy 1.0

# %%
# The predictions look like this
log_reg.predict(X_val_imputed)
# Out:
# array([False, False, False, False, False, False,  True, False, False,
#         True,  True, False, False, False,  True,  True, False,  True,
#         True,  True,  True, False, False,  True,  True,  True,  True,
#        False,  True,  True,  True, False,  True, False, False, False,
#        False,  True, False, False, False, False, False,  True,  True,
#        False, False, False,  True, False, False, False,  True,  True,
#        False, False, False, False,  True, False, False, False, False,
#        False,  True,  True, False,  True,  True, False,  True,  True,
#        False,  True, False, False, False,  True,  True,  True,  True,
#         True, False,  True,  True])

# %%
log_reg.predict_proba(X_val_imputed)
# Out:
# array([[0.96456456, 0.03543544],
#        [0.96456456, 0.03543544],
#        [0.96456456, 0.03543544],
#        [0.96456456, 0.03543544],
#        [0.96456456, 0.03543544],
#        [0.96560254, 0.03439746],
#        [0.05125409, 0.94874591],
#        [0.96456456, 0.03543544],
#        [0.96456456, 0.03543544],
#        [0.05125409, 0.94874591],
#        [0.05125409, 0.94874591],
#        [0.96456456, 0.03543544],
#        [0.96456456, 0.03543544],
#        [0.96456456, 0.03543544],
#        [0.05125409, 0.94874591],
#        [0.05125409, 0.94874591],
#        [0.96444837, 0.03555163],
#        [0.05125409, 0.94874591],
#        [0.05125409, 0.94874591],
#        [0.05125409, 0.94874591],
#        [0.05125409, 0.94874591],
#        [0.96216628, 0.03783372],
#        [0.96456456, 0.03543544],
#        [0.05125409, 0.94874591],
#        [0.05125409, 0.94874591],
#        [0.05125409, 0.94874591],
#        [0.05125409, 0.94874591],
#        [0.96456456, 0.03543544],
# ...

# %%
log_reg.coef_
# Out:
# array([[0.09226228, 0.16066087, 6.22230985]])

# %%
# The logistic sigmoid "squishing" function, 
# implemented to accept numpy arrays
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.e**(-x))

# 1 + np.e**(-2) 
1 + np.e**(-322222)
# Out:
# 1.0

# %%
# !pip install category_encoders

# %%
#Begin with baselines for classification.
#Use scikit-learn for logistic regression.



y_train = train[target]
y_train.value_counts(normalize=True)

from sklearn.model_selection import train_test_split

train, val = train_test_split(train, random_state=42)

train.shape, val.shape
# Out:
# ((223, 59), (75, 59))

# %%
# TODO
import category_encoders as ce 
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler


encoder = ce.OneHotEncoder(use_cat_names=True)
X_train_encoded = encoder.fit_transform(X_train)
X_val_encoded = encoder.transform(X_val)
# X_train_encoded.head()

imputer = SimpleImputer()
X_train_imputed = imputer.fit_transform(X_train_encoded)
X_val_imputed = imputer.transform(X_val_encoded)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_imputed)
X_val_scaled = scaler.transform(X_val_imputed)

model = LogisticRegression(random_state=42)
model.fit(X_train_scaled, y_train)
print ('Validation Accuracy', model.score(X_val_scaled,y_val))
#print ('Validation Accuracy', model.score(X_train_scaled,y_train))
# Out:
# Validation Accuracy 1.0
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
#Get your model's validation accuracy. (Multiple times if you try multiple iterations.)
#Get your model's test accuracy. (One time, at the end.)
